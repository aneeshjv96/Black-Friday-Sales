# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dcc555c2-a6be-4465-9b3b-e435e66cba32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dcc555c2-a6be-4465-9b3b-e435e66cba32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %%
df = pd.read_csv('train.csv')

# %%
df.shape
# Out:
# (550068, 12)

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df.head()
# Out:
#    User_ID Product_ID Gender  ... Product_Category_2  Product_Category_3 Purchase
# 0  1000001  P00069042      F  ...                NaN                 NaN     8370
# 1  1000001  P00248942      F  ...                6.0                14.0    15200
# 2  1000001  P00087842      F  ...                NaN                 NaN     1422
# 3  1000001  P00085442      F  ...               14.0                 NaN     1057
# 4  1000002  P00285442      M  ...                NaN                 NaN     7969
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3631
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               20
# Product_Category_2               17
# Product_Category_3               15
# Purchase                      18105
# dtype: int64

# %%
#Exploratory Data Analysis
plt.figure(figsize=(10,6))
sns.distplot(df['Purchase'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Gender'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['City_Category'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Occupation'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Marital_Status'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Occupation'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df[df['Occupation'] == 8].isnull().sum()
# Out:
# User_ID                          0
# Product_ID                       0
# Gender                           0
# Age                              0
# Occupation                       0
# City_Category                    0
# Stay_In_Current_City_Years       0
# Marital_Status                   0
# Product_Category_1               0
# Product_Category_2             421
# Product_Category_3            1004
# Purchase                         0
# dtype: int64

# %%
sns.countplot(df['Stay_In_Current_City_Years'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Bivariate analysis - using two attributes
Occupation_purchase = df.pivot_table(values = 'Purchase', columns = 'Occupation', aggfunc='mean')
Occupation_purchase
# Out:
# Occupation           0           1   ...           19           20
# Purchase    9124.428588  8953.19327  ...  8710.627231  8836.494905
#
# [1 rows x 21 columns]

# %%
#Preprocessing Data

#Filling Null vallues

df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df['Product_Category_2'] = df['Product_Category_2'].fillna(-1.0).astype('float')
df['Product_Category_3'] = df['Product_Category_3'].fillna(-1.0).astype('float')

# %%
Gender_dict = {'M':1, 'F':0}
df['Gender'] = df['Gender'].apply(lambda x: Gender_dict[x])

# %%
df.head()
# Out:
#    User_ID Product_ID  Gender  ... Product_Category_2  Product_Category_3 Purchase
# 0  1000001  P00069042       0  ...               -1.0                -1.0     8370
# 1  1000001  P00248942       0  ...                6.0                14.0    15200
# 2  1000001  P00087842       0  ...               -1.0                -1.0     1422
# 3  1000001  P00085442       0  ...               14.0                -1.0     1057
# 4  1000002  P00285442       1  ...               -1.0                -1.0     7969
#
# [5 rows x 12 columns]

# %%
cols = ['Age', 'City_Category', 'Stay_In_Current_City_Years']
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

for col in cols:
  df[col] = encoder.fit_transform(df[col])

df.head()
# Out:
#    User_ID Product_ID  Gender  ...  Product_Category_2  Product_Category_3  Purchase
# 0  1000001  P00069042       0  ...                -1.0                -1.0      8370
# 1  1000001  P00248942       0  ...                 6.0                14.0     15200
# 2  1000001  P00087842       0  ...                -1.0                -1.0      1422
# 3  1000001  P00085442       0  ...                14.0                -1.0      1057
# 4  1000002  P00285442       1  ...                -1.0                -1.0      7969
#
# [5 rows x 12 columns]

# %%
corr = df.corr()
plt.figure(figsize=(11,7))
sns.heatmap(corr, annot = True, cmap = "coolwarm")

# %%
df.head()
# Out:
#    User_ID Product_ID  Gender  ...  Product_Category_2  Product_Category_3  Purchase
# 0  1000001  P00069042       0  ...                -1.0                -1.0      8370
# 1  1000001  P00248942       0  ...                 6.0                14.0     15200
# 2  1000001  P00087842       0  ...                -1.0                -1.0      1422
# 3  1000001  P00085442       0  ...                14.0                -1.0      1057
# 4  1000002  P00285442       1  ...                -1.0                -1.0      7969
#
# [5 rows x 12 columns]

# %%
X = df.drop(columns = ['User_ID', 'Product_ID', 'Purchase'])
y = df['Purchase']
# Out:
# (550068,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 43)

# %%
plt.style.use('fivethirtyeight')
from sklearn.metrics import mean_squared_error
def train(model, X_train, y_train):
  model.fit(X_train, y_train)
  predict_y = model.predict(X_test)

  print('Results:',model)
  print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, predict_y)))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

train(model, X_train, y_train)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title='Model Coefficients')
# Out:
# Results: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# Root Mean Squared Error: 4625.593473417675

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
train(model, X_train, y_train)
features = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
features.plot(kind='bar', title='Feature Importance')
# Out:
# Results: DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')
# Root Mean Squared Error: 3339.1216854239656

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
train(model, X_train, y_train)
features = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
features.plot(kind='bar', title='Feature Importance')
# Out:
# Results: RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)
# Root Mean Squared Error: 3041.512259356665

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
train(model, X_train, y_train)
features = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
features.plot(kind='bar', title='Feature Importance')
# Out:
# Results: ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)
# Root Mean Squared Error: 3171.2356267133378
